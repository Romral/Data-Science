# %% [markdown]
# <h1>MINOR PROJECT</h1>
#
# <h3>Objective of this Analysis:</h3>
#
# To understand how the student's performance (test scores) is affected by the other variables (Gender, Ethnicity, Parental level of education, Lunch, Test preparation course).
#
# gender: Gender of the student
#
# race/ethnicity: Race of the Student As Group A/B/C
#
# parental level of education: What is the education Qualification of Student Parent
#
# lunch:Whether the lunch is Standard type/Free lunch or Some Discounted Lunch.
#
# test preparation course : Whether Student has Taken or not and Completed.
#
# math score : Scores in Maths
#
# reading score : Scores in Reading
#
# writing score : Scores in Writing
#
# <h2>Importing all required Libraries:</h2>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# <h2>Reading the csv file:</h2>

# %%
file = pd.read_csv('StudentsPerformance (3)(1).csv')
file.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# <h2>Checking for null values:</h2>

# %%
file.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# No null values are present in the dataset
#
# <h2>Numerical Variable Description:</h2>

# %%
file.describe().T
# Out:
#                 count    mean        std   min    25%   50%   75%    max
# math score     1000.0  66.089  15.163080   0.0  57.00  66.0  77.0  100.0
# reading score  1000.0  69.169  14.600192  17.0  59.00  70.0  79.0  100.0
# writing score  1000.0  68.054  15.195657  10.0  57.75  69.0  79.0  100.0

# %% [markdown]
# <h2>Finding the outliers or anamolies using boxplot:</h2>

# %%
file.boxplot()#['math score','reading score','writing score'])
plt.title('Boxplot of all the scores',fontsize=14)
plt.show()

# %% [markdown]
# <h3>Observations:</h3>
#
# The outlier of math score range between 0 till 25.
#
# The outlier of reading score range between 18 till 30.
#
# The outlier of writing score range between 10 till 22.
#
# <h2>CountPlot for Categorical variables:</h2>

# %%
cat_var = ['gender','race/ethnicity','parental level of education','lunch','test preparation course']
for i in cat_var:
    plt.figure(figsize=(10,6))
    sns.set_style("darkgrid")
    sns.countplot(x=i,data=file)
    plt.title("Countplot of "+i,fontsize=15)
    plt.show()

# %% [markdown]
# <h3>Observations:</h3>
#
# In Gender we analyzed that the count of female is more than male.
#
# In Race/Ethnicity we analyzed that the count of group A is least whereas group C is highest.
#
# In Parental Level Of Education we analyzed that the count of Master's Degree is least whereas some college is highest.
#
# In Lunch we analyzed that the count of Standard lunch is more than Free/reduced.
#
# In Test preparation course we analyzed that the count of none is more than completed.
#
# <h2>Variation of scores with race/ethnicity in terms of genders:</h2>

# %%
scores = ['math score','reading score','writing score']
for i in scores:
    plt.figure(figsize=(10,6))
    sns.barplot(x = 'race/ethnicity',y = i,hue = 'gender',data = file)
    plt.title("Variation of "+i+" with race/ethnicity",fontsize = 15)
    plt.show()

# %% [markdown]
# <h3>Observations:</h3>
#
# Group E seems to have the highest scores for all the scores especially the math score.For reading and writing the scores seem to not differ by a lot.
#
# Males scored more in math for all groups of Race/Ethnicity.
#
# Females scored more in reading and writing for all groups of Race/Ethnicity.
#
# <h3>Inference:</h3>
#
# Gender has chances of being an important variable for determining the scores.
#
# Race/Ethnicity has chances of holding some importance when it comes to scores.
#
# <h2>Variation of scores with parent level of education in terms of lunch:</h2>

# %%
scores = ['math score','reading score','writing score']
for i in scores :
    plt.figure(figsize=(10,6))
    sns.barplot(y = i,x='parental level of education',hue='lunch',data=file)
    plt.title("Variation of "+i+" with parental level of education",fontsize = 15)
    plt.show()

# %% [markdown]
# <h3>Observations:</h3>
#
# The standard lunch is dominating in all types of parental level of education for all the 3 scores.
#
# There is no extreme or clear distinction in scores for each category of Parental Level of Education as the scores don't differ a lot category-wise
#
# <h3>Inference:</h3>
#
# Lunch has high chances of being an important variable for determining the scores.
#
# Parental Level of Education has chances of not being an Important Variable.
#
# <h2>Variation of scores with test preparation course in terms of gender:</h2>

# %%
scores = ['math score','reading score','writing score']
for i in scores :
    plt.figure(figsize=(10,6))
    sns.barplot(y = i,x='test preparation course',hue = 'gender',data=file)
    plt.title("Variation of "+i+" with test preparation course",fontsize=15)
    plt.show()

# %% [markdown]
# <h3>Observations:</h3>
#
# Students who've completed the Test Preparation Course have scored more for the 3 scores.
#
# Males scored more in Maths.
#
# Females scored more in Writing and Reading.
#
# <h3>Inference:</h3>
#
# Test Preparation Course has high chances of being an important variable.
#
# Chances of Gender being an important variable Increases.
#
# <h2>Violin plot of different scores:</h2>

# %%
scores = ['math score','reading score','writing score']
for i in scores:
    plt.figure(figsize=(6,10))
    sns.violinplot(y=i,data=file)
    plt.title("Violinplot of "+i,fontsize = 14)
    plt.show()

# %% [markdown]
# <h3>Observations:</h3>
#
# From the above plots we analyzed that most of the students have scored between 60 and 80 for all the 3 scores.
#
# <h2>Histogram of the 3 Scores:</h2>

# %%
scores = ['math score','reading score','writing score']
for i in scores:
    plt.figure(figsize=(10,6))
    plt.hist(x=i,bins = 20,facecolor='brown',data=file)
    plt.xlabel("Score",fontsize=15)
    plt.ylabel("No. of Students",fontsize=15)
    plt.title("Histogram of "+i,fontsize=15)
    plt.show()

# %% [markdown]
# <h3>Observations</h3>
#
# Most of the students have scored in the range of 60-70 for Maths.
#
# Most of students have score in the range of 65-70 for Reading.
#
# Most of students have score in the range of 60-75 for Writing.
#
# <h2>Heatmap correlating the numeric values:</h2>

# %%
sns.heatmap(file.corr(),annot=True)
plt.title('Heatmap Correlating the numeric values',fontsize=14)
plt.show()

# %% [markdown]
# <h3>Observations:</h3>
#
# According to the Heatmap:
#
# For every increase in 100 scores in maths there is an increase of 82 scores and 80 scores in reading and writing respectively.
#
# For every increase in 100 scores in reading there is an increase of 82 scores and 95 scores in maths and writing respectively.
#
# For every increase in 100 scores in writing there is an increase of 80 scores and 95 scores in maths and reading respectively.
#
# <h2>Label Encoding:</h2>

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
file['gender']=le.fit_transform(file['gender'])
file['race/ethnicity']=le.fit_transform(file['race/ethnicity'])
file['parental level of education']=le.fit_transform(file['parental level of education'])
file['lunch']=le.fit_transform(file['lunch'])
file['test preparation course']=le.fit_transform(file['test preparation course'])

# %%
file.head()
# Out:
#    gender  race/ethnicity  parental level of education  lunch  \
# 0       0               1                            1      1
# 1       0               2                            4      1
# 2       0               1                            3      1
# 3       1               0                            0      0
# 4       1               2                            4      1
#
#    test preparation course  math score  reading score  writing score
# 0                        1          72             72             74
# 1                        0          69             90             88
# 2                        1          90             95             93
# 3                        1          47             57             44
# 4                        1          76             78             75

# %% [markdown]
# <h2>Heatmap correlating after Label Encoding:</h2>

# %%
sns.heatmap(file.corr(),annot=True)
plt.title('Heatmap correlating after the conversion of the variables',fontsize=14)
plt.show()

# %% [markdown]
# <h3>Observations:</h3>
#
# The Scores are least dependent on Parental Level of Education.
#
# <h2>Conclusion:</h2>
#
# Gender,Race/Ethnicity,Lunch and Test Preparation Course are important variables for the 3 scores.
#
# Test Preparation Course: Students who've completed the course have high chances of scoring better as observed in the bar graph.
#
# Lunch: Students receiving standard lunch have high chances of scoring better.
#
# Race/Ethnicity: Group E students tend to score better.
#
# Gender: Males tend to score better in maths while Females tend to score better in reading and writing.
#
# Parental Level of Education: Not an important variable.
