# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
import scipy.stats as stats
from scipy import stats, optimize, interpolate
from pandas.plotting import scatter_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn import model_selection
from sklearn.preprocessing import StandardScaler
import os

# %%
print(os.listdir())
# Out:
# ['-200315-183052.DS_Task_1 (2)', '.ipynb_checkpoints', '0001018360002233050_09152019_10052019.PDF', '0001018360002233050_10152019_11042019.PDF', '04032020_FNO_PLStatement.pdf', '051030821091905732_1569061807776.pdf', '09-Mar-2020_fno_ordertrades_16816.pdf', '1-2703290308698_314600869_enc.pdf', '1012.pdf', '10dimensionalityreductionwithpca1-200315-183245.ipynb', '12clustering1-200315-183239.ipynb', '1506.pdf', '1691.pdf', '1695.pdf', '17-Oct-2019_fno_ordertrades_15891.pdf', '17CS664- PYTHON-MODULE2-2020.pdf', '17CS664-PYTHON-MODULE 1-2020.pdf', '1RN17IS068', '1RN17IS068(Exam Application).pdf', '1RN17IS068(Pooja Ravi ).pdf', '1RN17IS068-Pooja Ravi (1).pdf', '1RN17IS068-Pooja Ravi.pdf', '1RN17IS068.pdf', '1RN17IS068.zip', '1st program-find s.pdf', '1TheHundredPageMLBook_byAndriyBurkov-191123-115139 (1).zip', '1TheHundredPageMLBook_byAndriyBurkov-191123-115139.zip', '20200210_OrderTrades_66816.pdf', '28-06-2018-TO-26-06-2020ICICIBANKEQN (1).csv', '28-06-2018-TO-26-06-2020ICICIBANKEQN (2).csv', '28-06-2018-TO-26-06-2020ICICIBANKEQN (3).csv', '28-06-2018-TO-26-06-2020ICICIBANKEQN (4).csv', '28-06-2018-TO-26-06-2020ICICIBANKEQN.csv', '28-06-2019-TO-26-06-2020ICICIBANKEQN.csv', '291920T001115883.pdf', '291920T001185836 (1).pdf', '291920T001185836.pdf', '291920T001224566.pdf', '2nd PU Dissolution HO.pdf', '320', '320.zip', '35531606_1573026014932.pdf', '4 IJITEE_Paper_Template  (1).doc', '4 IJITEE_Paper_Template .doc', '4854XXXXXXXXXX51_15-10-2019.PDF', '5068698-52540033868-560070.pdf', '560070_8509008631446_20200313_15308_NFO (1).pdf', '560070_8509008631446_20200313_15308_NFO.pdf', '680.pdf', '71410.pdf', '789418_1355863_bundle_archive.zip', '942.pdf', 'A4 print- site.pdf', 'abc.jpg', 'ACFrOgA9866XCW0iSGVPfdMKx4sSmkudc-flx0YNRymH5QKFuW5-MH4OfcT5QvGfr3aKoPC8SXiKCVrU7-6Qex1I_4J6Rgd6e9M0n1KC0Et474IGxB12t-ahysZjrEU=.pdf', 'addresses.csv', 'ADE_4.5_Installer.exe', 'admin.php', 'admin_assig_dates.php', 'Algebra.zip', 'All_models1-200315-183110.ipynb', 'AnyDesk (1).exe', 'AnyDesk.exe', 'apowermanager-setup.exe', 'Apr-oct2019.pdf', 'archive.zip', 'Assignment2 (1).ipynb', 'Assignment2 (2).ipynb', 'Assignment2 (3).ipynb', 'Assignment2.ipynb', 'Assignment2.py', 'Assignment3 (1).py', 'Assignment3.py', 'Assignment4.ipynb', 'attachments (1).zip', 'attachments (2).zip', 'attachments (3).zip', 'attachments (4).zip', 'attachments (5).zip', 'attachments (6).zip', 'attachments (7).zip', 'attachments (8).zip', 'attachments (9).zip', 'attachments.zip', 'Aug (1).pdf', 'Aug.pdf', 'average-monthly-temperat.pdf', 'A_Study_on_Contrast_and_Comparison_between_Bellman-Ford_algorithm_and_Dijkstras_Algorithms.pdf', 'B + tree (1).CPP', 'B + tree.CPP', 'bank.csv', 'bank3-200315-181336.csv', 'bankadditionalfull1-200315-184547.csv', 'Base Paper.docx', 'Boosting1-200315-184304.ipynb', 'C20190603000162_V0 (1).pdf', 'C20190603000162_V0.pdf', 'CamScanner 08-04-2020 20.57.44 (1).pdf', 'CamScanner 08-04-2020 20.57.44.pdf', 'CamScanner 08-08-2020 11.10.43 (1).pdf', 'CamScanner 08-08-2020 11.10.43.pdf', 'CHANGE-1.txt', 'change_details.php', 'Chapter12-Networks.pdf', 'Chapter6', 'check.php', 'chromedriver.exe', 'chromedriver_win32.zip', 'ChromeSetup.exe', 'citation-224408260.txt', 'ClassCodes1-200315-184624.zip', 'Clustering.zip', 'Clustering_gmm1-200315-184440.csv', 'CMR_404719_Sign.pdf', 'CN - Ques.pdf', 'cn mod2.pdf', 'cn mod3.pdf', 'CN-Lab-Manual-2018 (1).docx', 'CN-Lab-Manual-2018.docx', 'CN-Lab-Manual-2018.pdf', 'CNC Full  IS(1) (1).pdf', 'CNC Full  IS(1).pdf', 'combinepdf.pdf', 'company.php', 'companydetails.php', 'comp_select.php', 'Conference-template-A4 (1).doc', 'Conference-template-A4 (2).doc', 'Conference-template-A4 (3).doc', 'Conference-template-A4.doc', 'Contacts-2019-12-16(1).vcf', 'Coordinate_geometry1 (1).zip', 'Coordinate_geometry1 (2).zip', 'Coordinate_geometry1.zip', 'COVID_Arxive.pdf', 'create.php', 'Curr_Mrgn_Stmt_08-Jul-2019_458.pdf', 'Customer_DF1-200315-183104 (1).csv', 'Customer_DF1-200315-183104.csv', 'cust_transaction_details1-200315-183100.csv', ' ...

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Pooja ravi\\Downloads'

# %% [markdown]
# # Reading file and printing columns

# %%
df=pd.read_csv('framingham.csv')

# %%
df
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
# 4238     1   40        3.0              0         0.0     0.0
# 4239     0   39        3.0              1        30.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# 1                   0             0         0    250.0  121.0   81.0  28.73
# 2                   0             0         0    245.0  127.5   80.0  25.34
# 3                   0             1         0    225.0  150.0   95.0  28.58
# 4                   0             0         0    285.0  130.0   84.0  23.10
# ...               ...           ...       ...      ...    ...    ...    ...
# 4235                0             0         0    248.0  131.0   72.0  22.00
# 4236                0             0         0    210.0  126.5   87.0  19.16
# 4237                0             0         0    269.0  133.5   83.0  21.47
# 4238                0             1         0    185.0  141.0   98.0  25.60
# 4239                0             0         0    196.0  133.0   86.0  20.91
#
#       heartRate  glucose  TenYearCHD
# 0          80.0     77.0           0
# 1          95.0     76.0           0
# 2          75.0     70.0           0
# 3          65.0    103.0           1
# 4          85.0     85.0           0
# ...         ...      ...         ...
# 4235       84.0     86.0           0
# 4236       86.0      NaN           0
# 4237       80.0    107.0           0
# 4238       67.0     72.0           0
# 4239       85.0     80.0           0
#
# [4240 rows x 16 columns]

# %%
print("COLUMN NAMES:")
print("----------")
for col in df.columns:
    print(col)
    print("\n")
# Out:
# COLUMN NAMES:
# ----------
# male
#
#
# age
#
#
# education
#
#
# currentSmoker
#
#
# cigsPerDay
#
#
# BPMeds
#
#
# prevalentStroke
#
#
# prevalentHyp
#
#
# diabetes
#
#
# totChol
#
#
# sysBP
#
#
# diaBP
#
#
# BMI
#
#
# heartRate
#
#
# glucose
#
#
# TenYearCHD

# %% [markdown]
# # Handling missing values

# %%
df = df.replace(np.nan,0)

# %% [markdown]
# # Handling outliers

# %%
z_score = stats.zscore(df)
abs_z_score = np.abs(z_score)
filtered_entries = (abs_z_score<3).all(axis=1)
df = df[filtered_entries]
df
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4235     0   48        2.0              1        20.0     0.0
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
# 4238     1   40        3.0              0         0.0     0.0
# 4239     0   39        3.0              1        30.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# 1                   0             0         0    250.0  121.0   81.0  28.73
# 2                   0             0         0    245.0  127.5   80.0  25.34
# 3                   0             1         0    225.0  150.0   95.0  28.58
# 4                   0             0         0    285.0  130.0   84.0  23.10
# ...               ...           ...       ...      ...    ...    ...    ...
# 4235                0             0         0    248.0  131.0   72.0  22.00
# 4236                0             0         0    210.0  126.5   87.0  19.16
# 4237                0             0         0    269.0  133.5   83.0  21.47
# 4238                0             1         0    185.0  141.0   98.0  25.60
# 4239                0             0         0    196.0  133.0   86.0  20.91
#
#       heartRate  glucose  TenYearCHD
# 0          80.0     77.0           0
# 1          95.0     76.0           0
# 2          75.0     70.0           0
# 3          65.0    103.0           1
# 4          85.0     85.0           0
# ...         ...      ...         ...
# 4235       84.0     86.0           0
# 4236       86.0      0.0           0
# 4237       80.0    107.0           0
# 4238       67.0     72.0           0
# 4239       85.0     80.0           0
#
# [3811 rows x 16 columns]

# %% [markdown]
# # Handling duplicate values

# %%
df.duplicated(subset=None,keep='first')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4235    False
# 4236    False
# 4237    False
# 4238    False
# 4239    False
# Length: 3811, dtype: bool

# %% [markdown]
# # Exploratory Data Analysis

# %%
def draw_histograms(dataframe,features,rows,cols):
    fig=plt.figure(figsize=(20,20))
    for i,feature in enumerate(features):
        ax=fig.add_subplot(rows,cols,i+1)
        dataframe[feature].hist(bins=20,ax=ax,facecolor='midnightblue')
        ax.set_title(feature+"Distribution",color='DarkRed')
        fig.tight_layout()
    plt.show()

# %%
draw_histograms(df,df.columns,6,3)

# %%
df.TenYearCHD.value_counts()
# Out:
# 0    3301
# 1     510
# Name: TenYearCHD, dtype: int64

# %%
sns.countplot(x='TenYearCHD',data=df)
# Out:
# <AxesSubplot:xlabel='TenYearCHD', ylabel='count'>

# %%
sns.pairplot(data=df)

# %%
df.describe().T
# Out:
#                   count        mean        std     min      25%     50%  \
# male             3811.0    0.437418   0.496133    0.00    0.000    0.00
# age              3811.0   49.108895   8.460155   32.00   42.000   48.00
# education        3811.0    1.950144   1.058217    0.00    1.000    2.00
# currentSmoker    3811.0    0.501706   0.500063    0.00    0.000    1.00
# cigsPerDay       3811.0    8.937024  11.555718    0.00    0.000    0.00
# BPMeds           3811.0    0.000000   0.000000    0.00    0.000    0.00
# prevalentStroke  3811.0    0.000000   0.000000    0.00    0.000    0.00
# prevalentHyp     3811.0    0.268958   0.443476    0.00    0.000    0.00
# diabetes         3811.0    0.000000   0.000000    0.00    0.000    0.00
# totChol          3811.0  235.087903  42.155099  113.00  205.000  233.00
# sysBP            3811.0  129.836919  19.108108   83.50  116.000  127.00
# diaBP            3811.0   81.837969  10.740230   48.00   74.000   81.00
# BMI              3811.0   25.492173   3.650554   15.54   22.975   25.22
# heartRate        3811.0   75.372081  11.457606   44.00   68.000   75.00
# glucose          3811.0   72.612700  25.362818    0.00   68.000   76.00
# TenYearCHD       3811.0    0.133823   0.340507    0.00    0.000    0.00
#
#                     75%     max
# male               1.00    1.00
# age               56.00   69.00
# education          3.00    4.00
# currentSmoker      1.00    1.00
# cigsPerDay        20.00   43.00
# BPMeds             0.00    0.00
# prevalentStroke    0.00    0.00
# prevalentHyp       1.00    1.00
# diabetes           0.00    0.00
# totChol          261.00  382.00
# sysBP            141.00  198.00
# diaBP             88.00  118.00
# BMI               27.78   38.88
# heartRate         82.00  112.00
# glucose           85.00  163.00
# TenYearCHD         0.00    1.00

# %% [markdown]
# # Calculating basic statistics

# %%
print("MEAN :")
print("--------")
print(df.mean())
print("\n")
print("MEDIAN :")
print("--------")
print(df.median())
print("\n")
print("MODE :")
print("-------")
print(df.mode())
print("\n")
print("VARIANCE :")
print("--------")
print(df.var())
print("\n")
print("STANDARD DEVIATION :")
print("------------------")
print(df.std())
print("\n")
print("STANDARD ERROR :")
print("-----------")
print(df.sem())
# Out:
# MEAN :
# --------
# male                 0.437418
# age                 49.108895
# education            1.950144
# currentSmoker        0.501706
# cigsPerDay           8.937024
# BPMeds               0.000000
# prevalentStroke      0.000000
# prevalentHyp         0.268958
# diabetes             0.000000
# totChol            235.087903
# sysBP              129.836919
# diaBP               81.837969
# BMI                 25.492173
# heartRate           75.372081
# glucose             72.612700
# TenYearCHD           0.133823
# dtype: float64
#
#
# MEDIAN :
# --------
# male                 0.00
# age                 48.00
# education            2.00
# currentSmoker        1.00
# cigsPerDay           0.00
# BPMeds               0.00
# prevalentStroke      0.00
# prevalentHyp         0.00
# diabetes             0.00
# totChol            233.00
# sysBP              127.00
# diaBP               81.00
# BMI                 25.22
# heartRate           75.00
# glucose             76.00
# TenYearCHD           0.00
# dtype: float64
#
#
# MODE :
# -------
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     0   40        1.0              1         0.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    240.0  120.0   80.0  22.19       75.0      0.0
#
#    TenYearCHD
# 0           0
#
#
# VARIANCE :
# --------
# male                  0.246148
# age                  71.574228
# education             1.119823
# currentSmoker         0.250063
# cigsPerDay          133.534616
# BPMeds                0.000000
# prevalentStroke       0.000000
# prevalentHyp          0.196671
# diabetes              0.000000
# totChol            1777.052376
# sysBP               365.119789
# diaBP               115.352545
# BMI                  13.326543
# heartRate           131.276743
# glucose             643.272532
# TenYearCHD            0.115945
# dtype: float64
#
#
# STANDARD DEVIATION :
# ------------------
# male                0.496133
# age                 8.460155
# education           1.058217
# currentSmoker       0.500063
# cigsPerDay         11.555718
# BPMeds              0.000000
# prevalentStroke     0.000000
# prevalentHyp        0.443476
# diabetes            0.000000
# totChol            42.155099
# sysBP              19.108108
# diaBP              10.740230
# BMI                 3.650554
# heartRate          11.457606
# glucose            25.362818
# TenYearCHD          0.340507
# dtype: float64
#
#
# STANDARD ERROR :
# -----------
# male               0.008037
# age                0.137044
# education          0.017142
# currentSmoker      0.008100
# cigsPerDay         0.187188
# BPMeds             0.000000
# prevalentStroke    0.000000
# prevalentHyp       0.007184
# diabetes           0.000000
# totChol            0.682858
# sysBP              0.309527
# diaBP              0.173978
# BMI                0.059134
# heartRate          0.185598
# glucose            0.410845
# TenYearCHD         0.005516
# dtype: float64

# %% [markdown]
# # Columns - important to predict heart disease

# %%
data = df[['age','diaBP','totChol','cigsPerDay','heartRate','TenYearCHD']]

# %%
array = data.values
X = array[:,0:6]
Y = array[:,5]
print(X)
X_train, X_validation, Y_train, Y_validation = train_test_split(X,Y,test_size=0.4, random_state=5)
norm = StandardScaler()
X_train = norm.fit_transform(X_train)
X_validation = norm.fit_transform(X_validation)
print(X_train)
# Out:
# [[ 39.  70. 195.   0.  80.   0.]
#  [ 46.  81. 250.   0.  95.   0.]
#  [ 48.  80. 245.  20.  75.   0.]
#  ...
#  [ 52.  83. 269.   0.  80.   0.]
#  [ 40.  98. 185.   0.  67.   0.]
#  [ 39.  86. 196.  30.  85.   0.]]
# [[-0.83856867 -0.74382977  0.43175988  0.09757124  1.10796994 -0.38791508]
#  [ 0.72886223  1.30382947  0.12402418 -0.77644071 -0.28454977 -0.38791508]
#  [ 0.48771901 -0.09230183  1.94676641  0.97158319  0.41171009 -0.38791508]
#  ...
#  [ 0.60829062  0.27999985 -0.46777525  0.97158319 -1.15487458 -0.38791508]
#  [-0.83856867  0.23346214 -0.79918293  1.84559514  1.2820349  -0.38791508]
#  [-0.23571064 -0.92998061  1.63903071  0.97158319  0.84687249  2.57788381]]

# %%
models =[]
models.append(('LR',LogisticRegression(solver='liblinear',multi_class='ovr')))
#models.append(('LDA',LinearDiscriminantAnalysis()))
models.append(('KNN',KNeighborsClassifier()))
models.append(('NB',GaussianNB()))
models.append(('SVM',SVC(gamma='auto')))

# %%
model = LogisticRegression()
model.fit(X_train,Y_train)
y_pred = model.predict(X_validation)
model.score(X_validation,Y_validation)*100
# Out:
# 100.0

# %%
results = []
names = []
print("Model\tAccuracy Mean\t\tAccuracy Standard Deviation")
for name,model in models:
    kfold = StratifiedKFold(n_splits=10)
    cv_results = cross_val_score(model,X_train,Y_train,cv=kfold,scoring='accuracy')
    #print(cv_results)
    results.append(cv_results)
    names.append(name)
    print('%s:\t%f\t\t%f' % (name, cv_results.mean(),cv_results.std()))
# Out:
# Model	Accuracy Mean		Accuracy Standard Deviation
# LR:	1.000000		0.000000
# KNN:	1.000000		0.000000
# NB:	1.000000		0.000000
# SVM:	1.000000		0.000000

# %% [markdown]
# SVM and Linear Regression have the same accuracy
#
# Standard deviation is comparatively less for SVM
#
# So SVM is preferred

# %%
plt.boxplot(results, labels=names)
plt.title('Algorithm Comparison')
plt.show()

# %%
model = SVC(gamma='auto')
model.fit(X_train,Y_train)
prediction = model.predict(X_validation)

# %%
print(accuracy_score(Y_validation, prediction))
print(confusion_matrix(Y_validation, prediction))#prediction matrix
print(classification_report(Y_validation, prediction))
# Out:
# 0.8701639344262295
# [[1327    0]
#  [ 198    0]]
#               precision    recall  f1-score   support
#
#          0.0       0.87      1.00      0.93      1327
#          1.0       0.00      0.00      0.00       198
#
#     accuracy                           0.87      1525
#    macro avg       0.44      0.50      0.47      1525
# weighted avg       0.76      0.87      0.81      1525
# C:\Users\KIIT\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
